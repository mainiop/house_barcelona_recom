# %%
import json
import pandas as pd
import folium
import geopandas as gpd
from shapely.geometry import Polygon
import pandas as pd

# %%
with open('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Json_geografico/cinema.geojson', 'r') as file:
    data = json.load(file)
# Out:
# {'type': 'FeatureCollection', 'generator': 'overpass-turbo', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.', 'timestamp': '2025-01-11T15:32:41Z', 'features': [{'type': 'Feature', 'properties': {'@id': 'way/65294302', 'amenity': 'cinema', 'building': 'yes'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.4012331, 41.5538962], [2.4011675, 41.5539639], [2.4010229, 41.5538639], [2.4011009, 41.553813], [2.4011007, 41.5538169], [2.4012331, 41.5538962]]]}, 'id': 'way/65294302'}, {'type': 'Feature', 'properties': {'@id': 'way/125697822', 'addr:city': 'Granollers', 'addr:housenumber': '4', 'addr:postcode': '08400', 'addr:street': 'Carrer del Montseny', 'amenity': 'cinema', 'building:levels': '2', 'building:part': 'yes', 'contact:email': 'granollers@aki.es', 'contact:fax': '+34 93 8404939', 'contact:phone': '+34 93 8491086', 'contact:website': 'https://www.aki.es', 'name': 'Ocine Granollers - El Nord'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.3016431, 41.6099851], [2.3019145, 41.609477], [2.3024613, 41.6096407], [2.3021908, 41.6101476], [2.3016431, 41.6099851]]]}, 'id': 'way/125697822'}, {'type': 'Feature', 'properties': {'@id': 'way/132535607', 'amenity': 'cinema', 'building': 'public', 'building:levels': '2', 'building:levels:underground': '2', 'name': 'Cinema Bosque', 'name:ca': 'Cinema Bosque', 'wheelchair': 'no', 'wikidata': 'Q17588344', 'wikimedia_commons': 'Category:Cinemes Bosque', 'wikipedia': 'ca:Cinema Bosque'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.1513906, 41.4017259], [2.1513571, 41.4017049], [2.151282, 41.4016577], [2.1512066, 41.4016105], [2.1512441, 41.401548], [2.1512687, 41.4014973], [2.1514051, 41.4013757], [2.151431, 41.4013527], [2.1514814, 41.4013076], [2.1515025, 41.401289], [2.1515272, 41.4012669], [2.1515433, 41.4012525], [2.1517638, 41.4013932], [2.151997, 41.4015408], [2.1519718, 41.4015629], [2.1519324, 41.4015975], [2.15189, 41.4016346], [2.1518395, 41.401679], [2.1517963, 41.4017167], [2.1517675, 41.401742], [2.1517402, 41.4017659], [2.1517315, 41.4017735], [2.1517245, 41.4017795], [2.1517115, 41.4017908], [2.1516596, 41.401758], [2.1516521, 41.4017687], [2.1515443, 41.4018222], [2.1514498, 41.401763], [2.1514141, 41.4017407], [2.1513906, 41.4017259]]]}, 'id': 'way/132535607'}, {'type': 'Feature', 'properties': {'@id': 'way/147085468', 'amenity': 'cinema', 'architect': 'Mateo architects', 'building': 'public', 'building:levels': '5', 'building:levels:underground': '2', 'contact:facebook': 'https://es-es.facebook.com/filmotecadecatalunya/', 'contact:instagram': 'https://www.instagram.com/filmotecacat/', 'contact:twitter': 'https://twitter.com/filmotecacat', 'contact:vimeo': 'https://vimeo.com/filmotecacat', 'contact:youtube': 'https://www.youtube.com/user/filmotecacat', 'name': 'Filmoteca de Catalunya', 'name:ca': 'Filmoteca de Catalunya', 'name:es': 'Filmoteca de Cataluña', 'operator': 'Generalitat de Catalunya', 'website': 'https://www.filmoteca.cat/', 'wikidata': 'Q4894418', 'wikimedia_commons': 'Category:Filmoteca de Catalunya', 'wikipedia': 'ca:Filmoteca de Catalunya'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.1708707, 41.37873], [2.1708257, 41.3787669], [2.170641, 41.3786387], [2.1706856, 41.3786023], [2.1707364, 41.3785607], [2.1710563, 41.3782992], [2.1712395, 41.3784274], [2.1711622, 41.3784918], [2.1711112, 41.3785335], [2.1710634, 41.3785726], [2.1709231, 41.3786872], [2.1708707, 41.37873]]]}, 'id': 'way/147085468'}, {'type': 'Feature', 'properties': {'@id': 'way/186349753', 'amenity': 'cinema', 'building': 'apartments', 'name': 'Cinemes Imperial', 'name:ca': 'Cinemes Imperial'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.1121908, 41.5411921], [2.1122857, 41.540999], [2.1123204, 41.5410079], [2.112377, 41.5408912], [2.1124228, 41.5409037], [2.1124634, 41.5409149], [2.1125086, 41.5409271], [2.1125521, 41.540939], [2.11259, 41.5409497], [2.1126399, 41.5409631], [2.1126815, 41. ...

# %%
df = pd.DataFrame(data)
# Out:
#                  type       generator  \
# 0   FeatureCollection  overpass-turbo
# 1   FeatureCollection  overpass-turbo
# 2   FeatureCollection  overpass-turbo
# 3   FeatureCollection  overpass-turbo
# 4   FeatureCollection  overpass-turbo
# ..                ...             ...
# 59  FeatureCollection  overpass-turbo
# 60  FeatureCollection  overpass-turbo
# 61  FeatureCollection  overpass-turbo
# 62  FeatureCollection  overpass-turbo
# 63  FeatureCollection  overpass-turbo
#
#                                             copyright             timestamp  \
# 0   The data included in this document is from www...  2025-01-11T15:32:41Z
# 1   The data included in this document is from www...  2025-01-11T15:32:41Z
# 2   The data included in this document is from www...  2025-01-11T15:32:41Z
# 3   The data included in this document is from www...  2025-01-11T15:32:41Z
# 4   The data included in this document is from www...  2025-01-11T15:32:41Z
# ..                                                ...                   ...
# 59  The data included in this document is from www...  2025-01-11T15:32:41Z
# 60  The data included in this document is from www...  2025-01-11T15:32:41Z
# 61  The data included in this document is from www...  2025-01-11T15:32:41Z
# 62  The data included in this document is from www...  2025-01-11T15:32:41Z
# 63  The data included in this document is from www...  2025-01-11T15:32:41Z
#
#                                              features
# 0   {'type': 'Feature', 'properties': {'@id': 'way...
# 1   {'type': 'Feature', 'properties': {'@id': 'way...
# 2   {'type': 'Feature', 'properties': {'@id': 'way...
# 3   {'type': 'Feature', 'properties': {'@id': 'way...
# 4   {'type': 'Feature', 'properties': {'@id': 'way...
# ..                                                ...
# 59  {'type': 'Feature', 'properties': {'@id': 'nod...
# 60  {'type': 'Feature', 'properties': {'@id': 'nod...
# 61  {'type': 'Feature', 'properties': {'@id': 'nod...
# 62  {'type': 'Feature', 'properties': {'@id': 'nod...
# 63  {'type': 'Feature', 'properties': {'@id': 'nod...
#
# [64 rows x 5 columns]

# %%
df = pd.json_normalize(df['features'])

# %%
df_geo = df[df['geometry.type']=='Polygon']
df_geo
# Out:
#        type              id  properties.@id properties.amenity  \
# 0   Feature    way/65294302    way/65294302             cinema
# 1   Feature   way/125697822   way/125697822             cinema
# 2   Feature   way/132535607   way/132535607             cinema
# 3   Feature   way/147085468   way/147085468             cinema
# 4   Feature   way/186349753   way/186349753             cinema
# 5   Feature   way/249402942   way/249402942             cinema
# 6   Feature   way/294184829   way/294184829             cinema
# 7   Feature   way/309688614   way/309688614             cinema
# 8   Feature   way/374524637   way/374524637             cinema
# 9   Feature   way/374525116   way/374525116             cinema
# 10  Feature   way/460088649   way/460088649             cinema
# 11  Feature   way/755111479   way/755111479             cinema
# 12  Feature  way/1084635508  way/1084635508             cinema
# 13  Feature  way/1145619954  way/1145619954             cinema
#
#    properties.building geometry.type  \
# 0                  yes       Polygon
# 1                  NaN       Polygon
# 2               public       Polygon
# 3               public       Polygon
# 4           apartments       Polygon
# 5               retail       Polygon
# 6                  yes       Polygon
# 7           apartments       Polygon
# 8                  yes       Polygon
# 9                  yes       Polygon
# 10          commercial       Polygon
# 11                 yes       Polygon
# 12                 NaN       Polygon
# 13                 yes       Polygon
#
#                                  geometry.coordinates  properties.addr:city  \
# 0   [[[2.4012331, 41.5538962], [2.4011675, 41.5539...                   NaN
# 1   [[[2.3016431, 41.6099851], [2.3019145, 41.6094...            Granollers
# 2   [[[2.1513906, 41.4017259], [2.1513571, 41.4017...                   NaN
# 3   [[[2.1708707, 41.37873], [2.1708257, 41.378766...                   NaN
# 4   [[[2.1121908, 41.5411921], [2.1122857, 41.5409...                   NaN
# 5   [[[2.1626757, 41.3817547], [2.1624133, 41.3819...             Barcelona
# 6   [[[2.0953941, 41.3257983], [2.0951668, 41.3257...  El Prat de Llobregat
# 7   [[[2.2514363, 41.9313803], [2.2514081, 41.9312...                   Vic
# 8   [[[1.810648, 41.2364693], [1.8110017, 41.23637...                   NaN
# 9   [[[1.810365, 41.2379437], [1.810579, 41.238018...                   NaN
# 10  [[[2.0402396, 41.3455855], [2.0402187, 41.3455...                   NaN
# 11  [[[2.3565552, 41.6396289], [2.3565532, 41.6398...                   NaN
# 12  [[[1.9025208, 41.5065598], [1.903028, 41.50680...                   NaN
# 13  [[[2.3198112, 41.4800287], [2.3199545, 41.4798...             El Masnou
#
#    properties.addr:housenumber properties.addr:postcode  ...  \
# 0                          NaN                      NaN  ...
# 1                            4                    08400  ...
# 2                          NaN                      NaN  ...
# 3                          NaN                      NaN  ...
# 4                          NaN                      NaN  ...
# 5                     135, 139                    08015  ...
# 6                          111                    08820  ...
# 7                           22                    08500  ...
# 8                          NaN                      NaN  ...
# 9                          NaN                      NaN  ...
# 10                         NaN                      NaN  ...
# 11                         NaN                      NaN  ...
# 12                         NaN                      NaN  ...
# 13                           7                    08320  ...
#
#    properties.name:2015-07-09 properties.name:2017 properties.name:2020  \
# 0                         NaN                  NaN                  NaN
# 1                         NaN                  NaN                  NaN
# 2                         NaN                  NaN                  NaN
# 3                         NaN                  NaN                  NaN
# 4                         NaN                  NaN                  NaN
# 5                         NaN                  NaN                  NaN
# 6                         NaN                  NaN                  NaN
# 7                         NaN                  NaN                  NaN
# 8                         NaN                  NaN                  NaN
# 9                         NaN                  NaN                  NaN
# 10                        NaN                  NaN                  NaN
# 11                        NaN                  NaN                  NaN
# 12                        NaN                  NaN                  NaN
# 13                        NaN                  NaN                  NaN
#
#    properties.survey:date properties.survey:date:2015 properties.addr:place  \
# 0                     NaN                         NaN                   NaN
# 1                     NaN                         NaN                   NaN
# 2                     NaN                         NaN                   NaN
# 3                     NaN                         NaN                   NaN
# 4                     NaN                         NaN                   NaN
# 5                     NaN                         NaN                   NaN
# 6                     NaN                         NaN                   NaN
# 7                     NaN                         NaN                   NaN
# 8                     NaN                         NaN                   NaN
# 9                     NaN                         NaN                   NaN
# 10                    NaN                         NaN                   NaN
# 11                    NaN                         NaN                   NaN
# 12                    NaN                         NaN                   NaN
# 13                    NaN                         NaN                   NaN
#
#    properties.payment:cash properties.facebook properties.name:en  \
# 0                      NaN                 NaN                NaN
# 1                      NaN                 NaN                NaN
# 2                      NaN                 NaN                NaN
# 3                      NaN                 NaN                NaN
# 4                      NaN                 NaN                NaN
# 5                      NaN                 NaN                NaN
# 6                      NaN                 NaN                NaN
# 7                      NaN                 NaN                NaN
# 8                      NaN                 NaN                NaN
# 9                      NaN                 NaN                NaN
# 10                     NaN                 NaN                NaN
# 11                     NaN                 NaN                NaN
# 12                     NaN                 NaN                NaN
# 13                     NaN                 NaN                NaN
#
#    properties.level:ref
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# 5                   NaN
# 6                   NaN
# 7                   NaN
# 8                   NaN
# 9                   NaN
# 10                  NaN
# 11                  NaN
# 12                  NaN
# 13                  NaN
#
# [14 rows x 68 columns]

# %%
def get_centroid(coords):

    polygon = Polygon(coords[0])  
    return polygon.centroid.x, polygon.centroid.y

df_geo[['latitude','longitude', ]] = df_geo['geometry.coordinates'].apply(lambda x: pd.Series(get_centroid(x) if isinstance(x, list) else (None, None)))

print(df_geo[['longitude', 'latitude']])
# Out:
#     longitude  latitude
# 0   41.553886  2.401131
# 1   41.609813  2.302052
# 2   41.401554  2.151585
# 3   41.378533  2.170941
# 4   41.541105  2.112506
# 5   41.381860  2.162327
# 6   41.325623  2.095372
# 7   41.931057  2.251454
# 8   41.236636  1.810832
# 9   41.238077  1.810541
# 10  41.345461  2.040457
# 11  41.639712  2.356338
# 12  41.506795  1.902677
# 13  41.479836  2.320044
# /tmp/ipykernel_57252/896362334.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo[['latitude','longitude', ]] = df_geo['geometry.coordinates'].apply(lambda x: pd.Series(get_centroid(x) if isinstance(x, list) else (None, None)))
# /tmp/ipykernel_57252/896362334.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo[['latitude','longitude', ]] = df_geo['geometry.coordinates'].apply(lambda x: pd.Series(get_centroid(x) if isinstance(x, list) else (None, None)))

# %%
df_geo = df_geo[['properties.name', 'longitude','latitude']]
df_geo
# Out:
#                properties.name  longitude  latitude
# 0                          NaN  41.553886  2.401131
# 1   Ocine Granollers - El Nord  41.609813  2.302052
# 2                Cinema Bosque  41.401554  2.151585
# 3       Filmoteca de Catalunya  41.378533  2.170941
# 4             Cinemes Imperial  41.541105  2.112506
# 5         Renoir Floridablanca  41.381860  2.162327
# 6                 Cinema Capri  41.325623  2.095372
# 7                    el Vigatà  41.931057  2.251454
# 8                    el Retiro  41.236636  1.810832
# 9                 Casino Prado  41.238077  1.810541
# 10       Cinemes Can Castellet  41.345461  2.040457
# 11                   l'Esbarjo  41.639712  2.356338
# 12                Yelmo Abrera  41.506795  1.902677
# 13                         NaN  41.479836  2.320044

# %%
df = df[df['geometry.type'] != 'Polygon']

# %%
df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])
# Out:
# /tmp/ipykernel_57252/1223702550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
# /tmp/ipykernel_57252/1223702550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])

# %%
df.columns
# Out:
# Index(['type', 'id', 'properties.@id', 'properties.amenity',
#        'properties.building', 'geometry.type', 'geometry.coordinates',
#        'properties.addr:city', 'properties.addr:housenumber',
#        'properties.addr:postcode', 'properties.addr:street',
#        'properties.building:levels', 'properties.building:part',
#        'properties.contact:email', 'properties.contact:fax',
#        'properties.contact:phone', 'properties.contact:website',
#        'properties.name', 'properties.building:levels:underground',
#        'properties.name:ca', 'properties.wheelchair', 'properties.wikidata',
#        'properties.wikimedia_commons', 'properties.wikipedia',
#        'properties.architect', 'properties.contact:facebook',
#        'properties.contact:instagram', 'properties.contact:twitter',
#        'properties.contact:vimeo', 'properties.contact:youtube',
#        'properties.name:es', 'properties.operator', 'properties.website',
#        'properties.brand', 'properties.brand:wikidata',
#        'properties.brand:wikipedia', 'properties.height', 'properties.note',
#        'properties.phone', 'properties.source', 'properties.email',
#        'properties.level', 'properties.building:colour',
#        'properties.roof:shape', 'properties.check_date',
#        'properties.opening_hours:signed', 'properties.cinema:3D',
#        'properties.opening_hours', 'properties.screen', 'properties.addr:full',
#        'properties.toilets:wheelchair', 'properties.alt_name',
#        'properties.addr:country', 'properties.drive_in', 'properties.bar',
#        'properties.old_name', 'properties.theatre',
#        'properties.amenity:2015-07-09', 'properties.name:2015-07-09',
#        'properties.name:2017', 'properties.name:2020',
#        'properties.survey:date', 'properties.survey:date:2015',
#        'properties.addr:place', 'properties.payment:cash',
#        'properties.facebook', 'properties.name:en', 'properties.level:ref',
#        'latitude', 'longitude'],
#       dtype='object')

# %%
df_2 = df[['properties.name', 'longitude','latitude']]
df_2
# Out:
#                           properties.name  longitude   latitude
# 14                  Cines Verdi Barcelona  41.404015   2.156881
# 15                   Verdi Park Barcelona  41.404389   2.157646
# 16                  CINESA 3D Parc Vallès  41.546955   2.024862
# 17                       Cinemes Montcada  41.494827   2.180575
# 18                           CINESA Porta  41.435407   2.180591
# 19                         OCine Badalona  41.443741   2.230480
# 20                        Cinesa Diagonal  41.393745   2.136358
# 21                     Glòries Multicines  41.405371   2.192880
# 22                                Comedia  41.389389   2.167580
# 23                     Cinemes Sant Cugat  41.469504   2.090117
# 24  Yelmo Cines Castelldefels (Anec blau)  41.282067   1.985802
# 25                 Gran Sarria Multicines  41.394582   2.134084
# 26                         Cine Eix Macià  41.556188   2.097029
# 27                      OCINE Sant Celoni  41.681510   2.488528
# 28                        Cinemes Full HD  41.347240   2.079066
# 29                                 Cinesa  41.295012   2.007927
# 30                    Cinema Bages Centre  41.724105   1.846900
# 31                       Cinema Catalunya  41.563223   2.010984
# 32                         Cinemes Girona  41.399613   2.164602
# 33                    Sala de Cinema. ETC  41.502795   2.104653
# 34                        Cinemes Boliche  41.395292   2.153631
# 35                      Balmes Multicines  41.407191   2.138640
# 36                        Ocine - El Nord  41.609850   2.302168
# 37                    multicines El Sucre  41.925489   2.246400
# 38                              Phenomena  41.409087   2.171806
# 39                            Espai Texas  41.402047   2.163635
# 40                                Zumzeig  41.377320   2.145027
# 41                       Odeon Multicines  41.241597   1.727138
# 42                           Cinema Maldà  41.383236   2.173900
# 43                    Arenas de Barcelona  41.376343   2.149044
# 44                        Filmax Gran Via  41.358317   2.128373
# 45                      Aribau Multicines  41.386102   2.162563
# 46                    Espai Plana de l'Om  41.723821   1.824537
# 47                              Cinema 5D  41.637332   2.728702
# 48                         YELMO CINES 3D  41.508489   2.137082
# 49                               CineBaix  41.381917   2.044876
# 50                CINESA 3D La Maquinista  41.439380   2.198410
# 51                          Cine Alhambra  41.686061   2.285550
# 52                     Cinema La Calandra  41.479932   2.319990
# 53                super Cines Puente Real  10.155917 -64.697390
# 54                                  Yelmo  41.483230   2.053782
# 55                                    NaN  41.424473   2.119450
# 56                       Teatre Principal  41.225442   1.723862
# 57                  Teatre Círcol Catòlic  41.224609   1.725384
# 58                                 Cinesa  41.410220   2.216553
# 59                        Foment Mataroní  41.540933   2.444668
# 60                          Cinema Edison  41.607356   2.282398
# 61                            Sala Mozart  41.614180   2.660329
# 62                              Kinepolis  41.555052   2.433414
# 63                              Kinepolis  41.555052   2.433414

# %% [markdown]
# # Descomentar solo cuando haya mezcla de poligonos y coordenadas, el iloc es donde finalizan los poligonos

# %%
# df_2.loc[:2108, 'latitude'] = df_2.loc[:2108, 'latitude'].apply(lambda x: x[0] if isinstance(x, list) else x)
# df_2.loc[:2108, 'longitude'] = df_2.loc[:2108, 'longitude'].apply(lambda x: x[1] if isinstance(x, list) else x)

# %%
df_2 =  pd.concat([df_geo, df_2], axis=0, ignore_index=True)

# %%
df_2
# Out:
#                properties.name  longitude  latitude
# 0                          NaN  41.553886  2.401131
# 1   Ocine Granollers - El Nord  41.609813  2.302052
# 2                Cinema Bosque  41.401554  2.151585
# 3       Filmoteca de Catalunya  41.378533  2.170941
# 4             Cinemes Imperial  41.541105  2.112506
# ..                         ...        ...       ...
# 59             Foment Mataroní  41.540933  2.444668
# 60               Cinema Edison  41.607356  2.282398
# 61                 Sala Mozart  41.614180  2.660329
# 62                   Kinepolis  41.555052  2.433414
# 63                   Kinepolis  41.555052  2.433414
#
# [64 rows x 3 columns]

# %%
df_2.to_csv('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Distancia_servicios/Datasets_distancias/cinema.csv', 
                       index = False, 
                       sep = ";")

# %%
# Consulta a overpass-turbo
# [out:json];
# area["name"="Barcelona"]->.searchArea;
# (
#   node["amenity"="fitness_centre"](area.searchArea);
#   way["amenity"="fitness_centre"](area.searchArea);
#   relation["amenity"="fitness_centre"](area.searchArea);
# );
# out body;
# >;
# out skel qt;
