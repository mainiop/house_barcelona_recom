# %%
import json
import pandas as pd
import folium

# %%
with open('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Json_geografico/escoles.geojson', 'r') as file:
    data = json.load(file)
# Out:
# {'type': 'FeatureCollection', 'generator': 'overpass-turbo', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.', 'timestamp': '2025-01-12T14:11:11Z', 'features': [{'type': 'Feature', 'properties': {'@id': 'relation/169819', 'amenity': 'school', 'building': 'school', 'name': 'Institut Verdaguer', 'name:ca': 'Institut Verdaguer', 'name:etymology:wikidata': 'Q379290', 'ref': '8013238', 'type': 'multipolygon', 'wikidata': 'Q61744669', '@geometry': 'center'}, 'geometry': {'type': 'Point', 'coordinates': [2.1870282, 41.3874002]}, 'id': 'relation/169819'}, {'type': 'Feature', 'properties': {'@id': 'relation/2776354', 'addr:city': 'Sant Adrià de Besòs', 'addr:housename': 'Escola Catalunya', 'addr:postcode': '08930', 'addr:street': 'Carrer de Lleida', 'alt_name': 'Escola Catalunya de Sant Adrià de Besòs', 'alt_name:ca': 'Escola Catalunya de Sant Adrià de Besòs', 'amenity': 'school', 'barrier': 'fence', 'contact:email': 'a803
# ...

# %%
df = pd.DataFrame(data)
# Out:
#                    type       generator  \
# 0     FeatureCollection  overpass-turbo
# 1     FeatureCollection  overpass-turbo
# 2     FeatureCollection  overpass-turbo
# 3     FeatureCollection  overpass-turbo
# 4     FeatureCollection  overpass-turbo
# ...                 ...             ...
# 1067  FeatureCollection  overpass-turbo
# 1068  FeatureCollection  overpass-turbo
# 1069  FeatureCollection  overpass-turbo
# 1070  FeatureCollection  overpass-turbo
# 1071  FeatureCollection  overpass-turbo
#
#                                               copyright             timestamp  \
# 0     The data included in this document is from www...  2025-01-12T14:11:11Z
# 1     The data included in this document is from www...  2025-01-12T14:11:11Z
# 2     The data included in this document is from www...  2025-01-12T14:11:11Z
# 3     The data included in this document is from www...  2025-01-12T14:11:11Z
# 4     The data included in this document is from www...  2025-01-12T14:11:11Z
# ...

# %%
df = pd.json_normalize(df['features'])

# %%
df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])

# %%
df_2 = df[['properties.name', 'latitude', 'longitude']]
df_2
# Out:
#               properties.name  latitude  longitude
# 0          Institut Verdaguer  2.187028  41.387400
# 1            Escola Catalunya  2.226732  41.424381
# 2      Escola Galileo Galilei  2.086603  41.323859
# 3              Col·legi Ribas  2.036023  41.488349
# 4             Escola Jungfrau  2.243099  41.451705
# ...                       ...       ...        ...
# 1067  Escola de dansa - STAGE  2.177894  41.413435
# 1068               CFA Freire  2.175924  41.444699
# 1069          CFA Prosperitat  2.179489  41.444125
# 1070   Escola Concepcionistes  2.148630  41.405656
# 1071    Sant Francesc d'Assís  2.163380  41.385140
#
# [1072 rows x 3 columns]

# %%
df_2.to_csv('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Distancia_servicios/Dataset_coordenadas_servicios/escuelas.csv', 
                       index = False, 
                       sep = ";")
