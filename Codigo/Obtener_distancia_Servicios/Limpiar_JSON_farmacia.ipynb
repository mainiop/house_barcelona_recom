# %%
import json
import pandas as pd
import folium

# %%
with open('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Json_geografico/farmacia.geojson', 'r') as file:
    data = json.load(file)
# Out:
# {'type': 'FeatureCollection', 'generator': 'overpass-turbo', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.', 'timestamp': '2024-11-29T20:14:25Z', 'features': [{'type': 'Feature', 'properties': {'@id': 'node/82753755', 'addr:city': 'Barcelona', 'addr:full': 'carrer Ramon I Cajal, 24', 'addr:housenumber': '24', 'addr:postcode': '08012', 'addr:street': 'Carrer de Ramón y Cajal', 'amenity': 'pharmacy', 'check_date': '2024-11-14', 'contact:phone': '+34932135817', 'dispensing': 'yes', 'healthcare': 'pharmacy', 'name': 'Farmàcia Mauri Martínez, Emília', 'name:ca': 'Farmàcia Mauri', 'ref': '3622748', 'source': 'Generalitat de Catalunya', 'source:date': '03/11/2020 07:58:16 AM +0000'}, 'geometry': {'type': 'Point', 'coordinates': [2.1585725, 41.4025115]}, 'id': 'node/82753755'}, {'type': 'Feature', 'properties': {'@id': 'node/82781675', 'addr:city': 'Barcelona', 'addr:full': 'carrer Verdi, 7', 'addr:housenumber': '7', 'a
# ...

# %%
df = pd.DataFrame(data)
# Out:
#                    type       generator  \
# 0     FeatureCollection  overpass-turbo
# 1     FeatureCollection  overpass-turbo
# 2     FeatureCollection  overpass-turbo
# 3     FeatureCollection  overpass-turbo
# 4     FeatureCollection  overpass-turbo
# ...                 ...             ...
# 2366  FeatureCollection  overpass-turbo
# 2367  FeatureCollection  overpass-turbo
# 2368  FeatureCollection  overpass-turbo
# 2369  FeatureCollection  overpass-turbo
# 2370  FeatureCollection  overpass-turbo
#
#                                               copyright             timestamp  \
# 0     The data included in this document is from www...  2024-11-29T20:14:25Z
# 1     The data included in this document is from www...  2024-11-29T20:14:25Z
# 2     The data included in this document is from www...  2024-11-29T20:14:25Z
# 3     The data included in this document is from www...  2024-11-29T20:14:25Z
# 4     The data included in this document is from www...  2024-11-29T20:14:25Z
# ...

# %%
df = pd.json_normalize(df['features'])

# %%
df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])

# %%
df.columns
# Out:
# Index(['type', 'id', 'properties.@id', 'properties.addr:city',
#        'properties.addr:full', 'properties.addr:housenumber',
#        'properties.addr:postcode', 'properties.addr:street',
#        'properties.amenity', 'properties.check_date',
#        ...
#        'properties.name:de', 'properties.denomination',
#        'properties.survey:date:2016', 'properties.name:2021',
#        'properties.addr:flats', 'properties.name:-2020',
#        'properties.survey:date:2021', 'properties.name:2023', 'latitude',
#        'longitude'],
#       dtype='object', length=125)

# %%
df_2 = df[['properties.name', 'latitude', 'longitude']]
df_2
# Out:
#                                         properties.name  latitude  longitude
# 0                       Farmàcia Mauri Martínez, Emília  2.158573  41.402512
# 1     Farmàcia Valentines Nart, T - Gelabert Valentines  2.157597  41.403115
# 2                                  Farmàcia del diamant  2.155336  41.403947
# 3                        Farmàcia Bombardo Vial, Miquel  2.171587  41.376425
# 4                     Farmàcia Nieto Calm, Maria Dolors  2.173293  41.378241
# ...                                                 ...       ...        ...
# 2366                        Farmàcia Vives Singla, Emma  1.626475  41.582200
# 2367                Farmàcia Valles Queralt, Rosa Maria  1.605132  41.586464
# 2368                                       Farmacia Saz  2.175308  41.442676
# 2369                                                NaN  2.434641  41.555709
# 2370                                                NaN  2.431491  41.537367
#
# [2371 rows x 3 columns]

# %%
df_2.to_csv('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/farmacias_bcn.csv', 
                       index = False, 
                       sep = ";")
