# %%
import json
import pandas as pd
import folium

# %%
with open('Downloads/export (1).geojson', 'r') as file:
    data = json.load(file)
# Out:
# {'type': 'FeatureCollection', 'generator': 'overpass-turbo', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.', 'timestamp': '2024-11-29T18:58:44Z', 'features': [{'type': 'Feature', 'properties': {'@id': 'node/1708943387', 'defibrillator:access': 'yes', 'defibrillator:indoor': 'yes', 'defibrillator:location': 'Andana', 'defibrillator:location:en': 'Platfom', 'defibrillator:wheelchair:access': 'yes', 'emergency': 'defibrillator', 'name': 'Ecoparc', 'name:ca': 'Ecoparc', 'panoramax': '88891183-9dc5-403f-920a-29e7b55bf7be', 'platforms': '2', 'public_transport': 'station', 'railway': 'station', 'station': 'subway', 'subway': 'yes', 'survey:date': '2024-03-16', 'wheelchair': 'yes', 'wikidata': 'Q8842458', 'wikipedia': "ca:Estació d'Ecoparc"}, 'geometry': {'type': 'Point', 'coordinates': [2.1370899, 41.3301838]}, 'id': 'node/1708943387'}, {'type': 'Feature', 'properties': {'@id': 'node/1708943427', 'defibrillator:access': 'yes', 'defibrillator:indoor': 'yes', 'defibrillator:location': 'Andana central', 'defibrillator:location:en': 'Platform', 'defibrillator:wheelchair:access': 'yes', 'emergency': 'defibrillator', 'emergency:fire_extinguisher': 'yes', 'name': 'ZAL | Riu Vell', 'name:ca': 'ZAL | Riu Vell', 'panoramax': '95b61b76-beb1-40a1-be28-3266a81577c7', 'panoramax:0': 'd91cd95f-d5ee-404f-8756-0fc369d35174', 'platforms': '2', 'public_transport': 'station', 'railway': 'station', 'station': 'subway', 'subway': 'yes', 'survey:date': '2024-03-16', 'wheelchair': 'yes', 'wikidata': 'Q8842403', 'wikipedia': 'ca:Estació de ZAL - Riu Vell'}, 'geometry': {'type': 'Point', 'coordinates': [2.1331165, 41.3237458]}, 'id': 'node/1708943427'}, {'type': 'Feature', 'properties': {'@id': 'node/2992332327', 'access': 'yes', 'defibrillator:location': 'Andana 1', 'defibrillator:location:en': 'Platform 1', 'emergency': 'defibrillator', 'indoor': 'yes', 'level': '-2', 'name': 'El Prat Estació', 'name:ca': 'El Prat Estació', 'network': 'Metro de Barcelona', 'operator': 'Transports Metropolitans de Barcelona', 'public_transport': 'station', 'railway': 'station', 'share_taxi': 'no', 'start_date': '2016-02', 'station': 'subway', 'subway': 'yes', 'wheelchair': 'yes'}, 'geometry': {'type': 'Point', 'coordinates': [2.0901394, 41.3314023]}, 'id': 'node/2992332327'}, {'type': 'Feature', 'properties': {'@id': 'node/2992332329', 'check_date': '2024-08-23', 'defibrillator:access': 'yes', 'defibrillator:location': 'Andana via 1', 'defibrillator:location:en': 'Platform 1', 'defibrillator:survey:date': '2023-11-29', 'emergency': 'defibrillator', 'indoor': 'yes', 'level': '-2', 'name': 'Les Moreres', 'name:ca': 'Les Moreres', 'opening_date': '2016-02-16', 'public_transport': 'station', 'railway': 'station', 'station': 'subway', 'subway': 'yes', 'survey:date': '2023-11-10', 'wheelchair': 'yes', 'wikidata': 'Q4889321', 'wikipedia': 'ca:Estació de les Moreres'}, 'geometry': {'type': 'Point', 'coordinates': [2.1030715, 41.3289845]}, 'id': 'node/2992332329'}, {'type': 'Feature', 'properties': {'@id': 'node/2992352638', 'check_date': '2024-08-23', 'defibrillator:access': 'yes', 'defibrillator:location': 'Andana via 1', 'defibrillator:location:en': 'Platform 1', 'defibrillator:survey:date': '2023-11-29', 'emergency': 'defibrillator', 'indoor': 'yes', 'level': '-2', 'name': 'Mercabarna', 'name:ca': 'Mercabarna', 'network': 'Metro de Barcelona', 'operator': 'Transports Metropolitans de Barcelona', 'public_transport': 'station', 'railway': 'station', 'share_taxi': 'no', 'station': 'subway', 'subway': 'yes', 'wheelchair': 'yes', 'wikidata': 'Q4889330', 'wikipedia': 'ca:Estació de Mercabarna'}, 'geometry': {'type': 'Point', 'coordinates': [2.1112293, 41.3335696]}, 'id': 'node/2992352638'}, {'type': 'Feature', 'properties': {'@id': 'node/3397396364', 'covered': 'yes', 'defibrillator:access': 'yes', 'defibrillator:location': "Andana direcció Vall d'Hebron", 'defibrillator:location:en': "Platform to Vall d'Hebron",  ...

# %%
df = pd.DataFrame(data)
# Out:
#                   type       generator  \
# 0    FeatureCollection  overpass-turbo
# 1    FeatureCollection  overpass-turbo
# 2    FeatureCollection  overpass-turbo
# 3    FeatureCollection  overpass-turbo
# 4    FeatureCollection  overpass-turbo
# ..                 ...             ...
# 174  FeatureCollection  overpass-turbo
# 175  FeatureCollection  overpass-turbo
# 176  FeatureCollection  overpass-turbo
# 177  FeatureCollection  overpass-turbo
# 178  FeatureCollection  overpass-turbo
#
#                                              copyright             timestamp  \
# 0    The data included in this document is from www...  2024-11-29T18:58:44Z
# 1    The data included in this document is from www...  2024-11-29T18:58:44Z
# 2    The data included in this document is from www...  2024-11-29T18:58:44Z
# 3    The data included in this document is from www...  2024-11-29T18:58:44Z
# 4    The data included in this document is from www...  2024-11-29T18:58:44Z
# ..                                                 ...                   ...
# 174  The data included in this document is from www...  2024-11-29T18:58:44Z
# 175  The data included in this document is from www...  2024-11-29T18:58:44Z
# 176  The data included in this document is from www...  2024-11-29T18:58:44Z
# 177  The data included in this document is from www...  2024-11-29T18:58:44Z
# 178  The data included in this document is from www...  2024-11-29T18:58:44Z
#
#                                               features
# 0    {'type': 'Feature', 'properties': {'@id': 'nod...
# 1    {'type': 'Feature', 'properties': {'@id': 'nod...
# 2    {'type': 'Feature', 'properties': {'@id': 'nod...
# 3    {'type': 'Feature', 'properties': {'@id': 'nod...
# 4    {'type': 'Feature', 'properties': {'@id': 'nod...
# ..                                                 ...
# 174  {'type': 'Feature', 'properties': {'@id': 'nod...
# 175  {'type': 'Feature', 'properties': {'@id': 'nod...
# 176  {'type': 'Feature', 'properties': {'@id': 'nod...
# 177  {'type': 'Feature', 'properties': {'@id': 'nod...
# 178  {'type': 'Feature', 'properties': {'@id': 'nod...
#
# [179 rows x 5 columns]

# %%
df = pd.json_normalize(df['features'])

# %%
df
# Out:
#         type                id    properties.@id  \
# 0    Feature   node/1708943387   node/1708943387
# 1    Feature   node/1708943427   node/1708943427
# 2    Feature   node/2992332327   node/2992332327
# 3    Feature   node/2992332329   node/2992332329
# 4    Feature   node/2992352638   node/2992352638
# ..       ...               ...               ...
# 174  Feature   node/7515916367   node/7515916367
# 175  Feature   node/8939944750   node/8939944750
# 176  Feature  node/11436011991  node/11436011991
# 177  Feature  node/11438164378  node/11438164378
# 178  Feature  node/11883124918  node/11883124918
#
#     properties.defibrillator:access properties.defibrillator:indoor  \
# 0                               yes                             yes
# 1                               yes                             yes
# 2                               NaN                             NaN
# 3                               yes                             NaN
# 4                               yes                             NaN
# ..                              ...                             ...
# 174                             NaN                             NaN
# 175                             yes                             NaN
# 176                             NaN                             NaN
# 177                             NaN                             NaN
# 178                             yes                             yes
#
#     properties.defibrillator:location properties.defibrillator:location:en  \
# 0                              Andana                              Platfom
# 1                      Andana central                             Platform
# 2                            Andana 1                           Platform 1
# 3                        Andana via 1                           Platform 1
# 4                        Andana via 1                           Platform 1
# ..                                ...                                  ...
# 174                               NaN                                  NaN
# 175     Andana direcció Vall d'Hebron            Platform to Vall d'Hebron
# 176                               NaN                                  NaN
# 177                               NaN                                  NaN
# 178                      Andana via 1                           Platform 1
#
#     properties.defibrillator:wheelchair:access properties.emergency  \
# 0                                          yes        defibrillator
# 1                                          yes        defibrillator
# 2                                          NaN        defibrillator
# 3                                          NaN        defibrillator
# 4                                          NaN        defibrillator
# ..                                         ...                  ...
# 174                                        NaN                  NaN
# 175                                        NaN        defibrillator
# 176                                        NaN                  NaN
# 177                                        NaN                  NaN
# 178                                        NaN        defibrillator
#
#      properties.name  ... properties.emergency:location  \
# 0            Ecoparc  ...                           NaN
# 1     ZAL | Riu Vell  ...                           NaN
# 2    El Prat Estació  ...                           NaN
# 3        Les Moreres  ...                           NaN
# 4         Mercabarna  ...                           NaN
# ..               ...  ...                           ...
# 174         Sant Boi  ...                           NaN
# 175     Ernest Lluch  ...                           NaN
# 176       Mercat Nou  ...                           NaN
# 177   Plaça de Sants  ...                           NaN
# 178         Torrassa  ...                           NaN
#
#     properties.emergency_access properties.wikipedia:es  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
# ..                          ...                     ...
# 174                         NaN                     NaN
# 175                         NaN                     NaN
# 176                         NaN                     NaN
# 177                         NaN                     NaN
# 178                         NaN                     NaN
#
#     properties.defibrillator:location:fr properties.ref properties.image2  \
# 0                                    NaN            NaN               NaN
# 1                                    NaN            NaN               NaN
# 2                                    NaN            NaN               NaN
# 3                                    NaN            NaN               NaN
# 4                                    NaN            NaN               NaN
# ..                                   ...            ...               ...
# 174                                  NaN            NaN               NaN
# 175                                  NaN            NaN               NaN
# 176                                  NaN            NaN               NaN
# 177                                  NaN            NaN               NaN
# 178                                  NaN            NaN               NaN
#
#     properties.name:-2023 properties.name:ca:-2023 properties.location  \
# 0                     NaN                      NaN                 NaN
# 1                     NaN                      NaN                 NaN
# 2                     NaN                      NaN                 NaN
# 3                     NaN                      NaN                 NaN
# 4                     NaN                      NaN                 NaN
# ..                    ...                      ...                 ...
# 174                   NaN                      NaN                 NaN
# 175                   NaN                      NaN                 NaN
# 176                   NaN                      NaN                 NaN
# 177                   NaN                      NaN                 NaN
# 178                   NaN                      NaN                 NaN
#
#     properties.name:es
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ..                 ...
# 174                NaN
# 175                NaN
# 176         Mercat Nou
# 177                NaN
# 178                NaN
#
# [179 rows x 67 columns]

# %%
df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])

# %%
df.columns
# Out:
# Index(['type', 'id', 'properties.@id', 'properties.defibrillator:access',
#        'properties.defibrillator:indoor', 'properties.defibrillator:location',
#        'properties.defibrillator:location:en',
#        'properties.defibrillator:wheelchair:access', 'properties.emergency',
#        'properties.name', 'properties.name:ca', 'properties.panoramax',
#        'properties.platforms', 'properties.public_transport',
#        'properties.railway', 'properties.station', 'properties.subway',
#        'properties.survey:date', 'properties.wheelchair',
#        'properties.wikidata', 'properties.wikipedia', 'geometry.type',
#        'geometry.coordinates', 'properties.emergency:fire_extinguisher',
#        'properties.panoramax:0', 'properties.access', 'properties.indoor',
#        'properties.level', 'properties.network', 'properties.operator',
#        'properties.share_taxi', 'properties.start_date',
#        'properties.check_date', 'properties.defibrillator:survey:date',
#        'properties.opening_date', 'properties.covered', 'properties.source',
#        'properties.network:wikidata', 'properties.addr:city',
#        'properties.train', 'properties.piano', 'properties.uic_ref',
#        'properties.name:ru', 'properties.check_date:wheelchair',
#        'properties.intercambiador', 'properties.train_station',
#        'properties.emergency:indoor', 'properties.wikimedia_commons',
#        'properties.departures_board', 'properties.name:ja',
#        'properties.name:2022', 'properties.camera:mount',
#        'properties.camera:type', 'properties.man_made',
#        'properties.surveillance', 'properties.surveillance:type',
#        'properties.layer', 'properties.emergency:location',
#        'properties.emergency_access', 'properties.wikipedia:es',
#        'properties.defibrillator:location:fr', 'properties.ref',
#        'properties.image2', 'properties.name:-2023',
#        'properties.name:ca:-2023', 'properties.location', 'properties.name:es',
#        'longitud', 'latitud', 'latitude', 'longitude'],
#       dtype='object')

# %%
df_2 = df[['properties.name', 'latitude', 'longitude']]
df_2
# Out:
#      properties.name  latitude  longitude
# 0            Ecoparc  2.137090  41.330184
# 1     ZAL | Riu Vell  2.133116  41.323746
# 2    El Prat Estació  2.090139  41.331402
# 3        Les Moreres  2.103071  41.328984
# 4         Mercabarna  2.111229  41.333570
# ..               ...       ...        ...
# 174         Sant Boi  2.042951  41.348488
# 175     Ernest Lluch  2.112035  41.375895
# 176       Mercat Nou  2.133331  41.372795
# 177   Plaça de Sants  2.135323  41.375630
# 178         Torrassa  2.115630  41.368017
#
# [179 rows x 3 columns]

# %%
df_2.to_csv('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/estaciones_metro_bcn.csv', 
                       index = False, 
                       sep = ";")
