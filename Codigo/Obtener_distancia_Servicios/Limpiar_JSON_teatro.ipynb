# %%
import json
import pandas as pd
import folium
import geopandas as gpd

# %%
with open('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Json_geografico/teatro.geojson', 'r') as file:
    data = json.load(file)
# Out:
# {'type': 'FeatureCollection', 'generator': 'overpass-turbo', 'copyright': 'The data included in this document is from www.openstreetmap.org. The data is made available under ODbL.', 'timestamp': '2025-01-11T15:34:45Z', 'features': [{'type': 'Feature', 'properties': {'@id': 'relation/1716973', 'amenity': 'theatre', 'building': 'yes', 'name': 'Teatre de la Unió', 'name:ca': 'Teatre de la Unió', 'type': 'multipolygon'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.0799543, 41.4716715], [2.0800718, 41.4716348], [2.0800396, 41.4715183], [2.0802603, 41.4714764], [2.0804956, 41.4714318], [2.0806029, 41.4718157], [2.0802556, 41.4718842], [2.0800301, 41.471923], [2.0799811, 41.4717634], [2.0799543, 41.4716715]], [[2.0801949, 41.4717215], [2.0804191, 41.4716827], [2.0803874, 41.4715796], [2.0801631, 41.4716184], [2.0801949, 41.4717215]]]}, 'id': 'relation/1716973'}, {'type': 'Feature', 'properties': {'@id': 'relation/4123031', 'alt_name': 'Auditori Nacional de Catalunya', 'amenity': 'theatre', 'architect': 'Rafael Moneo', 'building': 'civic', 'building:levels': '4', 'culture': 'music', 'name': "L'Auditori", 'name:ca': "L'Auditori", 'type': 'multipolygon', 'wikidata': 'Q2713088', 'wikipedia': 'ca:Auditori de Barcelona'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.1863482, 41.3981743], [2.1861067, 41.3983565], [2.1858445, 41.3985543], [2.1855499, 41.3987764], [2.1857084, 41.3988947], [2.1855975, 41.3989783], [2.1854377, 41.398859], [2.1852512, 41.3989997], [2.1851251, 41.3990948], [2.1849373, 41.3992364], [2.1848781, 41.3992811], [2.1848457, 41.3992568], [2.1848102, 41.3992836], [2.1847594, 41.3993219], [2.1843935, 41.3990489], [2.1844443, 41.3990106], [2.1844797, 41.3989839], [2.1844371, 41.3989523], [2.1844986, 41.3989061], [2.1846829, 41.3987676], [2.1848145, 41.3986687], [2.1854048, 41.3982249], [2.1856675, 41.3980275], [2.1859411, 41.3978218], [2.1859711, 41.3978442], [2.1861, 41.3977469], [2.1861542, 41.3977874], [2.1861594, 41.3977912], [2.1860293, 41.3978893], [2.1863495, 41.3981282], [2.1863181, 41.3981519], [2.1863482, 41.3981743]], [[2.1849318, 41.3990683], [2.1851648, 41.3988923], [2.1849537, 41.3987355], [2.1847202, 41.3989119], [2.1847326, 41.3989313], [2.1847584, 41.3989614], [2.1847878, 41.3989906], [2.1848223, 41.3990162], [2.184858, 41.3990373], [2.1848969, 41.3990555], [2.1849318, 41.3990683]], [[2.1852292, 41.3986862], [2.1854438, 41.3986804], [2.1854517, 41.3985195], [2.1852361, 41.3985255], [2.1852292, 41.3986862]]]}, 'id': 'relation/4123031'}, {'type': 'Feature', 'properties': {'@id': 'relation/7431327', 'addr:city': 'Barcelona', 'addr:country': 'ES', 'addr:housenumber': '50', 'addr:postcode': '08030', 'addr:street': 'Carrer de Neopàtria', 'amenity': 'theatre', 'building': 'public', 'building:levels': '2', 'building:levels:underground': '2', 'name': 'Sant Andreu Teatre', 'name:ca': 'Sant Andreu Teatre', 'phone': '+34 933457930', 'short_name': 'SAT', 'type': 'multipolygon', 'website': 'https://www.sat-teatre.cat/', 'wheelchair': 'yes', 'wikidata': 'Q11946900', 'wikipedia': 'ca:Sant Andreu Teatre'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.1885374, 41.4303085], [2.1888192, 41.4303484], [2.1889687, 41.4303695], [2.1889104, 41.4305971], [2.1888823, 41.4307067], [2.1886611, 41.4306791], [2.1886525, 41.4307147], [2.1884284, 41.430667], [2.1882459, 41.4306281], [2.1881743, 41.4306129], [2.1880081, 41.4305775], [2.1879784, 41.4305699], [2.1879406, 41.4305594], [2.1880173, 41.4302372], [2.1882037, 41.4302373], [2.1882008, 41.4302608], [2.188383, 41.4302866], [2.1884949, 41.4303025], [2.1885374, 41.4303085]]]}, 'id': 'relation/7431327'}, {'type': 'Feature', 'properties': {'@id': 'relation/8282630', 'amenity': 'theatre', 'building': 'public', 'building:levels': '8', 'building:levels:underground': '1', 'name': 'Teatre Municipal Josep Maria de Segarra', 'name:ca': 'Teatre Municipal Josep Maria de Segarra', 'type': 'multipolygon'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[2.2045994, 41.4510987] ...

# %%
df = pd.DataFrame(data)
# Out:
#                   type       generator  \
# 0    FeatureCollection  overpass-turbo
# 1    FeatureCollection  overpass-turbo
# 2    FeatureCollection  overpass-turbo
# 3    FeatureCollection  overpass-turbo
# 4    FeatureCollection  overpass-turbo
# ..                 ...             ...
# 238  FeatureCollection  overpass-turbo
# 239  FeatureCollection  overpass-turbo
# 240  FeatureCollection  overpass-turbo
# 241  FeatureCollection  overpass-turbo
# 242  FeatureCollection  overpass-turbo
#
#                                              copyright             timestamp  \
# 0    The data included in this document is from www...  2025-01-11T15:34:45Z
# 1    The data included in this document is from www...  2025-01-11T15:34:45Z
# 2    The data included in this document is from www...  2025-01-11T15:34:45Z
# 3    The data included in this document is from www...  2025-01-11T15:34:45Z
# 4    The data included in this document is from www...  2025-01-11T15:34:45Z
# ..                                                 ...                   ...
# 238  The data included in this document is from www...  2025-01-11T15:34:45Z
# 239  The data included in this document is from www...  2025-01-11T15:34:45Z
# 240  The data included in this document is from www...  2025-01-11T15:34:45Z
# 241  The data included in this document is from www...  2025-01-11T15:34:45Z
# 242  The data included in this document is from www...  2025-01-11T15:34:45Z
#
#                                               features
# 0    {'type': 'Feature', 'properties': {'@id': 'rel...
# 1    {'type': 'Feature', 'properties': {'@id': 'rel...
# 2    {'type': 'Feature', 'properties': {'@id': 'rel...
# 3    {'type': 'Feature', 'properties': {'@id': 'rel...
# 4    {'type': 'Feature', 'properties': {'@id': 'rel...
# ..                                                 ...
# 238  {'type': 'Feature', 'properties': {'@id': 'nod...
# 239  {'type': 'Feature', 'properties': {'@id': 'nod...
# 240  {'type': 'Feature', 'properties': {'@id': 'nod...
# 241  {'type': 'Feature', 'properties': {'@id': 'nod...
# 242  {'type': 'Feature', 'properties': {'@id': 'nod...
#
# [243 rows x 5 columns]

# %%
df = pd.json_normalize(df['features'])

# %%
df_geo = df[df['geometry.type']=='Polygon']
df_geo
# Out:
#         type                id    properties.@id properties.amenity  \
# 0    Feature  relation/1716973  relation/1716973            theatre
# 1    Feature  relation/4123031  relation/4123031            theatre
# 2    Feature  relation/7431327  relation/7431327            theatre
# 3    Feature  relation/8282630  relation/8282630            theatre
# 4    Feature  relation/8827467  relation/8827467            theatre
# ..       ...               ...               ...                ...
# 113  Feature    way/1097924038    way/1097924038            theatre
# 114  Feature    way/1107755680    way/1107755680            theatre
# 115  Feature    way/1245573648    way/1245573648            theatre
# 116  Feature    way/1257775672    way/1257775672            theatre
# 117  Feature    way/1324960693    way/1324960693            theatre
#
#     properties.building                          properties.name  \
# 0                   yes                        Teatre de la Unió
# 1                 civic                               L'Auditori
# 2                public                       Sant Andreu Teatre
# 3                public  Teatre Municipal Josep Maria de Segarra
# 4                   yes          Teatre la Passió d'Esparreguera
# ..                  ...                                      ...
# 113                 yes                      Teatre de Palafolls
# 114                 yes                                      NaN
# 115              public                        Teatre del Centre
# 116                 yes                     Auditori de Cornellà
# 117                 yes                                   Teatre
#
#                           properties.name:ca properties.type geometry.type  \
# 0                          Teatre de la Unió    multipolygon       Polygon
# 1                                 L'Auditori    multipolygon       Polygon
# 2                         Sant Andreu Teatre    multipolygon       Polygon
# 3    Teatre Municipal Josep Maria de Segarra    multipolygon       Polygon
# 4            Teatre la Passió d'Esparreguera    multipolygon       Polygon
# ..                                       ...             ...           ...
# 113                      Teatre de Palafolls             NaN       Polygon
# 114                                      NaN             NaN       Polygon
# 115                                      NaN             NaN       Polygon
# 116                                      NaN             NaN       Polygon
# 117                                      NaN             NaN       Polygon
#
#                                   geometry.coordinates  ...  \
# 0    [[[2.0799543, 41.4716715], [2.0800718, 41.4716...  ...
# 1    [[[2.1863482, 41.3981743], [2.1861067, 41.3983...  ...
# 2    [[[2.1885374, 41.4303085], [2.1888192, 41.4303...  ...
# 3    [[[2.2045994, 41.4510987], [2.2045906, 41.4510...  ...
# 4    [[[1.8723189, 41.5349654], [1.8722248, 41.5348...  ...
# ..                                                 ...  ...
# 113  [[[2.7484554, 41.6681428], [2.74853, 41.668278...  ...
# 114  [[[2.0184747, 41.5686167], [2.0184935, 41.5686...  ...
# 115  [[[2.1787056, 41.5354933], [2.1788254, 41.5353...  ...
# 116  [[[2.0816203, 41.3490944], [2.0818718, 41.3491...  ...
# 117  [[[2.2842575, 41.9009805], [2.2842685, 41.9010...  ...
#
#     properties.entrance properties.survey:date properties.survey:date:2016  \
# 0                   NaN                    NaN                         NaN
# 1                   NaN                    NaN                         NaN
# 2                   NaN                    NaN                         NaN
# 3                   NaN                    NaN                         NaN
# 4                   NaN                    NaN                         NaN
# ..                  ...                    ...                         ...
# 113                 NaN                    NaN                         NaN
# 114                 NaN                    NaN                         NaN
# 115                 NaN                    NaN                         NaN
# 116                 NaN                    NaN                         NaN
# 117                 NaN                    NaN                         NaN
#
#     properties.contact:phone:ticket_office properties.addr:neighbourhood  \
# 0                                      NaN                           NaN
# 1                                      NaN                           NaN
# 2                                      NaN                           NaN
# 3                                      NaN                           NaN
# 4                                      NaN                           NaN
# ..                                     ...                           ...
# 113                                    NaN                           NaN
# 114                                    NaN                           NaN
# 115                                    NaN                           NaN
# 116                                    NaN                           NaN
# 117                                    NaN                           NaN
#
#     properties.capacity properties.image properties.addr:unit  \
# 0                   NaN              NaN                  NaN
# 1                   NaN              NaN                  NaN
# 2                   NaN              NaN                  NaN
# 3                   NaN              NaN                  NaN
# 4                   NaN              NaN                  NaN
# ..                  ...              ...                  ...
# 113                 NaN              NaN                  NaN
# 114                 NaN              NaN                  NaN
# 115                 NaN              NaN                  NaN
# 116                 NaN              NaN                  NaN
# 117                 NaN              NaN                  NaN
#
#     properties.year_of_construction properties.source:date
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ..                              ...                    ...
# 113                             NaN                    NaN
# 114                             NaN                    NaN
# 115                             NaN                    NaN
# 116                             NaN                    NaN
# 117                             NaN                    NaN
#
# [118 rows x 105 columns]

# %%
from shapely.geometry import Polygon
import pandas as pd

def get_centroid(coords):
    polygon = Polygon(coords[0])
    return polygon.centroid.x, polygon.centroid.y
df_geo[['latitude','longitude', ]] = df_geo['geometry.coordinates'].apply(lambda x: pd.Series(get_centroid(x) if isinstance(x, list) else (None, None)))
# Out:
#      longitude  latitude
# 0    41.471685  2.080281
# 1    41.398579  2.185384
# 2    41.430476  2.188452
# 3    41.450874  2.204968
# 4    41.534678  1.872439
# ..         ...       ...
# 113  41.668281  2.748262
# 114  41.568660  2.018249
# 115  41.535466  2.178853
# 116  41.349428  2.081694
# 117  41.901261  2.284199
#
# [118 rows x 2 columns]
# /tmp/ipykernel_57439/896362334.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo[['latitude','longitude', ]] = df_geo['geometry.coordinates'].apply(lambda x: pd.Series(get_centroid(x) if isinstance(x, list) else (None, None)))
# /tmp/ipykernel_57439/896362334.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_geo[['latitude','longitude', ]] = df_geo['geometry.coordinates'].apply(lambda x: pd.Series(get_centroid(x) if isinstance(x, list) else (None, None)))

# %%
df_geo = df_geo[['properties.name', 'longitude','latitude']]
df_geo
# Out:
#                              properties.name  longitude  latitude
# 0                          Teatre de la Unió  41.471685  2.080281
# 1                                 L'Auditori  41.398579  2.185384
# 2                         Sant Andreu Teatre  41.430476  2.188452
# 3    Teatre Municipal Josep Maria de Segarra  41.450874  2.204968
# 4            Teatre la Passió d'Esparreguera  41.534678  1.872439
# ..                                       ...        ...       ...
# 113                      Teatre de Palafolls  41.668281  2.748262
# 114                                      NaN  41.568660  2.018249
# 115                        Teatre del Centre  41.535466  2.178853
# 116                     Auditori de Cornellà  41.349428  2.081694
# 117                                   Teatre  41.901261  2.284199
#
# [118 rows x 3 columns]

# %%
df = df[df['geometry.type'] != 'Polygon']

# %%
df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])
# Out:
# /tmp/ipykernel_57439/1223702550.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['latitude'] = df['geometry.coordinates'].apply(lambda x: x[0])
# /tmp/ipykernel_57439/1223702550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['longitude'] = df['geometry.coordinates'].apply(lambda x: x[1])

# %%
df.columns
# Out:
# Index(['type', 'id', 'properties.@id', 'properties.amenity',
#        'properties.building', 'properties.name', 'properties.name:ca',
#        'properties.type', 'geometry.type', 'geometry.coordinates',
#        ...
#        'properties.survey:date:2016', 'properties.contact:phone:ticket_office',
#        'properties.addr:neighbourhood', 'properties.capacity',
#        'properties.image', 'properties.addr:unit',
#        'properties.year_of_construction', 'properties.source:date', 'latitude',
#        'longitude'],
#       dtype='object', length=107)

# %%
df_2 = df[['properties.name', 'longitude','latitude']]
df_2
# Out:
#                 properties.name  longitude  latitude
# 118         Teatre Tantarantana  41.375947  2.167338
# 119                Blas Infante  41.437700  2.222921
# 120                Teatre Romea  41.380532  2.171081
# 121        Auditorium municipal  41.486684  2.188224
# 122            Teatre de Ponent  41.611812  2.286897
# ..                          ...        ...       ...
# 238             La Nau Espacial  41.799281  2.225178
# 239  Teatre Plaza Castelldefels  41.279170  1.979370
# 240                         NaN  41.492595  2.185488
# 241         Auditori Can Batlló  41.369195  2.137277
# 242     Centre Cívic i Cultural  41.633789  2.164308
#
# [125 rows x 3 columns]

# %% [markdown]
# # Descomentar solo cuando haya mezcla de poligonos y coordenadas, el iloc es donde finalizan los poligonos

# %%
# df_2.loc[:2108, 'latitude'] = df_2.loc[:2108, 'latitude'].apply(lambda x: x[0] if isinstance(x, list) else x)
# df_2.loc[:2108, 'longitude'] = df_2.loc[:2108, 'longitude'].apply(lambda x: x[1] if isinstance(x, list) else x)

# %%
df_2 =  pd.concat([df_geo, df_2], axis=0, ignore_index=True)

# %%
df_2
# Out:
#                              properties.name  longitude  latitude
# 0                          Teatre de la Unió  41.471685  2.080281
# 1                                 L'Auditori  41.398579  2.185384
# 2                         Sant Andreu Teatre  41.430476  2.188452
# 3    Teatre Municipal Josep Maria de Segarra  41.450874  2.204968
# 4            Teatre la Passió d'Esparreguera  41.534678  1.872439
# ..                                       ...        ...       ...
# 238                          La Nau Espacial  41.799281  2.225178
# 239               Teatre Plaza Castelldefels  41.279170  1.979370
# 240                                      NaN  41.492595  2.185488
# 241                      Auditori Can Batlló  41.369195  2.137277
# 242                  Centre Cívic i Cultural  41.633789  2.164308
#
# [243 rows x 3 columns]

# %%
df_2.to_csv('/TFM Mercado Inmobiliario - Kschool/Metodología de Modelado/9. Código y datasets/Barcelona/Datasets/Distancia_servicios/Datasets_distancias/teatro.csv', 
                       index = False, 
                       sep = ";")

# %%
# [out:json];
# area["name"="Barcelona"]->.searchArea;
# (
#   node["amenity"="fitness_centre"](area.searchArea);
#   way["amenity"="fitness_centre"](area.searchArea);
#   relation["amenity"="fitness_centre"](area.searchArea);
# );
# out body;
# >;
# out skel qt;
